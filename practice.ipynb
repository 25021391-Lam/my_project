# %% [markdown]
# ###HW2
#
# ####Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a, b = map(float,input().split())
s = a*b
p = (a+b)*2
print("dien tich cua hinh chu nhat la")
print("chu vi cua hinh chu nhat la")
