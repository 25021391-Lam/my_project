# %% [markdown]
# ### HW1
# #### Nhap vao so nguyen n, in ra man hinh so gap doi cua n

# %%
n =  int(input())
n = n*2
print(n)
# Out:
# 4

# %% [markdown]
# ###HW2
# ####mot khu dat hinh chu nhat co chieu rong a, chieu dai b. Nguoi ta xay mot khu vui choi hinh tron tai vi tri trung tam khu dat. Nhap vao a,b. Hay tinh phan dien tich con de trong cay xung quanh la bao nhieu. Biet pi= 3,14, lay ket qua den 2 chu so phan thap phan

# %%
a, b = map(float, input().split())
s1= a*b
s2= 3.14*(a/2)
print(f"{s1-s2:.2f}")
# Out:
# 4.29

# %% [markdown]
# ###HW3
#
# ####Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input()
if (c.islower()):
    print(chr(ord(c) - 32))
else:
    print(chr(ord(c) + 32))
# Out:
# H

# %% [markdown]
# ###HW4
#
# ####Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input("nhap mot ky tu: ")
if c.isalpha() and len(c) == 1:
    print(f"{c} la ky tu alphabet")
else:
    print(f"{c} khong phai la ky tu alphabet")
# Out:
# c la ky tu alphabet

# %% [markdown]
# ###HW5
#
# #### Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input("Nhap chu cai hoa = ")
chu_thuong = c.lower()
if c == "A":
    print("z")
else:
    ket_qua = chr(ord(chu_thuong) - 1)
    print(ket_qua)
# Out:
# j

# %% [markdown]
# ###HW6
# #### Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c = map(float, input().split())
if a + b > c and a + c >b and b + c > a:
    p = (a + b + c)/2
    s = (p * (p-a) * (p-b) * (p-c)) ** 0.5
    print(f'{s:.1f}')
else:
    print('khong phai 3 canh cua tam giac')
# Out:
# khong phai 3 canh cua tam giac

# %% [markdown]
# ###HW7
# #### Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
s = input("nhap vao mot chuoi ky tu thuong (it nhat 20 ky tu)")
if len(s) >= 20:
    chu_thu_5 = s[4]
    chu_thu_9 = s[8]
    print(f'chu thu nam la: {chu_thu_5}')            
    print(f'chu thu chin la: {chu_thu_9}')
else:
    print("khong chay duoc")
# Out:
# chu thu nam la: p
# chu thu chin la: o

# %% [markdown]
# ###HW8
# #### Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:

# %%
ten_chu_ho = input('Ho va Ten')
print(f'Ho va Ten la: {ten_chu_ho}')
chi_so_thang_truoc = int(input('chi so thang truoc:'))
print(f'chi so thang truoc la: {chi_so_thang_truoc}')
chi_so_thang_nay = int(input('chi so thang nay:'))
print(f'chi so thang nay la: {chi_so_thang_nay}')
so_dien_da_dung = chi_so_thang_nay - chi_so_thang_truoc
print(f'So dien da dung la: {so_dien_da_dung}')
if so_dien_da_dung <= 50:
    s = so_dien_da_dung * 1984 * (1 + 8/100) 
    print(f'Tien phai tra la: {s:.0f}')
elif 51 <= so_dien_da_dung <=100:
    s = so_dien_da_dung * 2050 * (1 + 8/100)
    print(f'Tien phai tra la: {s:.0f}')
elif 101 <= so_dien_da_dung <= 200:
    s = so_dien_da_dung * 2380 * (1 + 8/100)
    print(f'Tien phai tra la: {s:.0f}')
elif 201 <= so_dien_da_dung <= 300:
    s = so_dien_da_dung * 2998 * (1 + 8/100)
    print(f'Tien phai tra lf: {s:.0f}')
elif 301 <= so_dien_da_dung <= 400:
    s = so_dien_da_dung * 3350 * (1 + 8/100)
    print(f'Tien phai tra la: {s:.0f}')
elif so_dien_da_dung > 401:
    s = so_dien_da_dung * 3460 * (1 + 8/100)
    print(f'Tien phai tra la: {s:.0f}')
# Out:
# Ho va Ten la: hai
# chi so thang truoc la: 2000
# chi so thang nay la: 2586
# So dien da dung la: 586
# Tien phai tra la: 2189765

# %% [markdown]
# ###HW9
# #### Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.
